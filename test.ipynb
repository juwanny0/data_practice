# %%
import pandas as pd
data = pd.read_parquet('/home/robotis/Downloads/data_practice/Task_000200_Put_PotLib_Lift13_CBG_lerobot_fail_example/data/chunk-000/episode_000000.parquet')

# %%
data.head(100)
# Out:
#     index  episode_index  task_index  subtask_index  timestamp  \
# 0       0              0           0              0   0.000000
# 1       1              0           0              0   0.066667
# 2       2              0           0              0   0.133333
# 3       3              0           0              0   0.200000
# 4       4              0           0              0   0.266667
# ..    ...            ...         ...            ...        ...
# 95     95              0           0              0   6.333333
# 96     96              0           0              0   6.400000
# 97     97              0           0              0   6.466667
# 98     98              0           0              0   6.533333
# 99     99              0           0              0   6.600000
#
#                                                action  \
# 0   [0.2127, 0.52, 0.0685, -1.792, 0.1741, 0.0, -1...
# 1   [0.2127, 0.52, 0.0685, -1.792, 0.1741, 0.0, -1...
# ...
